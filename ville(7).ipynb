# %%
import pandas as pd 
import numpy as np
import geopandas as gpd
from shapely.geometry import Point
from geopandas import GeoDataFrame
import matplotlib.pyplot as plt
import requests
# Out:
# /Users/emiliehogg/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# 1 - OUVERTURE FICHIER EQUIPEMENT CULTUREL

# %%
df_lieu_equip_cult = pd.read_csv('./Data/base-des-lieux-et-des-equipements-culturels.csv', sep =";")
df_lieu_equip_cult.head(5)
# Out:
# /var/folders/bp/dnh9b6751vvd2k84wnrwvz300000gn/T/ipykernel_29613/4195843643.py:1: DtypeWarning: Columns (14,22,23,29,30,33,34,41,44,45,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_lieu_equip_cult = pd.read_csv('./Data/base-des-lieux-et-des-equipements-culturels.csv', sep =";")
#                                               Source  \
# 0  Ministère de la Culture - Service du livre et ...
# 1  Ministère de la Culture - Service du livre et ...
# 2  Ministère de la Culture - Service du livre et ...
# 3  Ministère de la Culture - Service du livre et ...
# 4  Ministère de la Culture - Service du livre et ...
#
#                                        Nom                     Adresse  \
# 0                  Bibliothèque de GAMARde         348 RUE ABBE BORDES
# 1       Médiathèque de GRENAde-SUR-L'ADOUR         32 RUE DES CAPUCINS
# 2  LUDO-Bibliothèque MUNICIPALE de LABENNE        14 RUE DU PRESBYTERE
# 3    Bibliothèque MUNICIPALE de LABOUHEYRE  46 RUE FRANÇOIS MITTERRAND
# 4                    Médiathèque de LABRIT           30 ROUTE DE LUXEY
#
#   Complement Adresse  Code Postal libelle_geographique code_insee  \
# 0                NaN      40380.0    Gamarde-les-Bains      40104
# 1                NaN      40270.0  Grenade-sur-l'Adour      40117
# 2                NaN      40530.0              Labenne      40133
# 3                NaN      40210.0           Labouheyre      40134
# 4                NaN      40420.0               Labrit      40135
#
#   Code Insee Arrondt Identifiant origine Type équipement ou lieu  ...  \
# 0                401              LI7887            Bibliothèque  ...
# 1                402              LI7890            Bibliothèque  ...
# 2                401              LI1735            Bibliothèque  ...
# 3                402              LI1736            Bibliothèque  ...
# 4                402              LI7899            Bibliothèque  ...
#
#   Annee_Label_Appellation          Latitude           Longitude  \
# 0                     NaN  43.7325530845461  -0.873206140912455
# 1                     NaN   43.772152205146  -0.429404631079996
# 2                     NaN  43.5959632032077   -1.42775664273915
# 3                     NaN  44.2133421363569  -0.918764424591646
# 4                     NaN  44.1050991899747  -0.545001121981277
#
#   Demographie_AP            Demographie_detail_entree  \
# 0          Actif  historiquement dans la base en 2020
# 1          Actif  historiquement dans la base en 2020
# 2          Actif  historiquement dans la base en 2020
# 3          Actif  historiquement dans la base en 2020
# 4          Actif  historiquement dans la base en 2020
#
#   Démographie_detail_sortie Multi_equipements identifiant_QPV_24  \
# 0                       NaN               NaN                NaN
# 1                       NaN               NaN                NaN
# 2                       NaN               NaN                NaN
# 3                       NaN               NaN                NaN
# 4                       NaN               NaN                NaN
#
#   identifiant_QPV_15                       coordonnees_geo
# 0                NaN  43.7325530845461, -0.873206140912455
# 1                NaN   43.772152205146, -0.429404631079996
# 2                NaN   43.5959632032077, -1.42775664273915
# 3                NaN  44.2133421363569, -0.918764424591646
# 4                NaN  44.1050991899747, -0.545001121981277
#
# [5 rows x 54 columns]

# %%
df_lieu_equip_cult.iloc[:,10].unique()
# Out:
# array([nan, 'Centre d’art contemporain d’intérêt national',
#        'Centre chorégraphique national',
#        'Centre de développement chorégaphique national',
#        'Centre dramatique national', 'Art et essai',
#        'Architecture contemporaine remarquable',
#        'Centre national des arts de la rue et de l’espace public',
#        "Fonds régional d'art contemporain", 'Jardin remarquable',
#        'LIR - Librairie indépendante de référence',
#        'LR - Librairie de référence', 'Maison des illustres',
#        'Microfolie', 'Monument national', 'Monument historique',
#        'Musée de France', 'Opéra national en région',
#        'Pôle national cirque', 'Centre culturel de rencontre',
#        'Scène conventionnée d’intérêt national', 'Scène nationale',
#        'Scène de musiques actuelles', 'Théâtre hors label',
#        'Théâtre national', 'Théâtre privé', 'Théâtre de ville',
#        "Patrimoine mondial de l'Unesco", 'Zénith',
#        'Site patrimonial remarquable',
#        'Centre national de la marionnette',
#        'Orchestre national en région', 'Itinéraire culturel européen',
#        'Compagnie avec lieu', 'Centre national de création musicale',
#        'Opéra national', 'Etablissement public national',
#        "Théatre lyrique d'intérêt national", 'Musée national'],
#       dtype=object)

# %% [markdown]
# 2- NEW FICHIER POPULATION

# %%
df_population= pd.read_csv('./Data/datapopulation.csv', sep =";", header = 2)
df_population
# Out:
#         Code                  Libellé     Population municipale 2021
# 0      01001  L'Abergement-Clémenciat                            832
# 1      01002    L'Abergement-de-Varey                            267
# 2      01004        Ambérieu-en-Bugey                          14854
# 3      01005      Ambérieux-en-Dombes                           1897
# 4      01006                  Ambléon                            113
# ...      ...                      ...                            ...
# 34930  97613            M'Tsangamouji  N/A - résultat non disponible
# 34931  97614                 Ouangani  N/A - résultat non disponible
# 34932  97615                 Pamandzi  N/A - résultat non disponible
# 34933  97616                     Sada  N/A - résultat non disponible
# 34934  97617                 Tsingoni  N/A - résultat non disponible
#
# [34935 rows x 3 columns]

# %%
df_population.isna().sum()
# Out:
# Code                          0
# Libellé                       0
# Population municipale 2021    0
# dtype: int64

# %%
df_population['Population municipale 2021'].value_counts()['N/A - résultat non disponible']
# Out:
# np.int64(20)

# %%
len(df_population['Population municipale 2021'])
# Out:
# 34935

# %%
df_population['Population municipale 2021'] = df_population['Population municipale 2021'].map(lambda x : 0 if x == 'N/A - résultat non disponible' else x)

# %%
'N/A - résultat non disponible'
# Out:
# 'N/A - résultat non disponible'

# %%
df_population
# Out:
#         Code                  Libellé Population municipale 2021
# 0      01001  L'Abergement-Clémenciat                        832
# 1      01002    L'Abergement-de-Varey                        267
# 2      01004        Ambérieu-en-Bugey                      14854
# 3      01005      Ambérieux-en-Dombes                       1897
# 4      01006                  Ambléon                        113
# ...      ...                      ...                        ...
# 34930  97613            M'Tsangamouji                          0
# 34931  97614                 Ouangani                          0
# 34932  97615                 Pamandzi                          0
# 34933  97616                     Sada                          0
# 34934  97617                 Tsingoni                          0
#
# [34935 rows x 3 columns]

# %%
df_population['Population municipale 2021']
# Out:
# 0          832
# 1          267
# 2        14854
# 3         1897
# 4          113
#          ...
# 34930        0
# 34931        0
# 34932        0
# 34933        0
# 34934        0
# Name: Population municipale 2021, Length: 34935, dtype: object

# %% [markdown]
# 2/  - POPULATION Création nouveau datframe pour villes fdont population supérieur > 20 000 habitants et < 20 000 habitants

# %%
df_population
# Out:
#         Code                  Libellé Population municipale 2021
# 0      01001  L'Abergement-Clémenciat                        832
# 1      01002    L'Abergement-de-Varey                        267
# 2      01004        Ambérieu-en-Bugey                      14854
# 3      01005      Ambérieux-en-Dombes                       1897
# 4      01006                  Ambléon                        113
# ...      ...                      ...                        ...
# 34930  97613            M'Tsangamouji                          0
# 34931  97614                 Ouangani                          0
# 34932  97615                 Pamandzi                          0
# 34933  97616                     Sada                          0
# 34934  97617                 Tsingoni                          0
#
# [34935 rows x 3 columns]

# %%
df_population_integrer = df_population['Population municipale 2021'].astype(int)
df_population_integrer
# Out:
# 0          832
# 1          267
# 2        14854
# 3         1897
# 4          113
#          ...
# 34930        0
# 34931        0
# 34932        0
# 34933        0
# 34934        0
# Name: Population municipale 2021, Length: 34935, dtype: int64

# %%
df_grandes_villes = df_population_integrer[df_population_integrer > 20000]
df_grandes_villes
# Out:
# 47        41525
# 239       22277
# 781       24021
# 1053      52958
# 1081      28705
#           ...
# 34908    105240
# 34909     84077
# 34911     34344
# 34913     24293
# 34915     81943
# Name: Population municipale 2021, Length: 481, dtype: int64

# %%
df_petites_villes = df_population_integrer[df_population_integrer < 20000]
df_petites_villes
# Out:
# 0          832
# 1          267
# 2        14854
# 3         1897
# 4          113
#          ...
# 34930        0
# 34931        0
# 34932        0
# 34933        0
# 34934        0
# Name: Population municipale 2021, Length: 34454, dtype: int64

# %%
len(df_petites_villes)
# Out:
# 34454

# %% [markdown]
# 2/ GEOPOINTS -ouverture fichier

# %%
df_geopoints= pd.read_csv('./Data/villes_france_etl.csv', sep =",")


df_geopoints.head()
# Out:
#   insee_code            city_code  zip_code                label   latitude  \
# 0      25620        ville du pont     25650        ville du pont  46.999873
# 1      25624       villers grelot     25640       villers grelot  47.361512
# 2      25615  villars les blamont     25310  villars les blamont  47.368384
# 3      25619        les villedieu     25240        les villedieu  46.713906
# 4      25622        villers buzon     25170        villers buzon  47.228558
#
#    longitude department_name department_number              region_name  \
# 0   6.498147           doubs                25  bourgogne-franche-comté
# 1   6.235167           doubs                25  bourgogne-franche-comté
# 2   6.871415           doubs                25  bourgogne-franche-comté
# 3   6.265831           doubs                25  bourgogne-franche-comté
# 4   5.852187           doubs                25  bourgogne-franche-comté
#
#        region_geojson_name
# 0  Bourgogne-Franche-Comté
# 1  Bourgogne-Franche-Comté
# 2  Bourgogne-Franche-Comté
# 3  Bourgogne-Franche-Comté
# 4  Bourgogne-Franche-Comté

# %% [markdown]
# 2/ GEOPOINTS - Récupérer Latitude et Longitude avec codes postaux

# %%
df_geopoints.rename(columns={'zip_code': 'Codepostaux'}, inplace=True)

# %%
df_geopoints
# Out:
#       insee_code            city_code  Codepostaux                label  \
# 0          25620        ville du pont        25650        ville du pont
# 1          25624       villers grelot        25640       villers grelot
# 2          25615  villars les blamont        25310  villars les blamont
# 3          25619        les villedieu        25240        les villedieu
# 4          25622        villers buzon        25170        villers buzon
# ...          ...                  ...          ...                  ...
# 39140      98829                 thio        98829                 thio
# 39141      98831                  voh        98833                  voh
# 39142      98832                 yate        98834                 yate
# 39143      98612               sigave        98620               sigave
# 39144      98613                 uvea        98600                 uvea
#
#         latitude   longitude     department_name department_number  \
# 0      46.999873    6.498147               doubs                25
# 1      47.361512    6.235167               doubs                25
# 2      47.368384    6.871415               doubs                25
# 3      46.713906    6.265831               doubs                25
# 4      47.228558    5.852187               doubs                25
# ...          ...         ...                 ...               ...
# 39140        NaN         NaN  nouvelle-calédonie               988
# 39141        NaN         NaN  nouvelle-calédonie               988
# 39142        NaN         NaN  nouvelle-calédonie               988
# 39143 -14.270411 -178.155263    wallis-et-futuna               986
# 39144 -13.281863 -176.161928    wallis-et-futuna               986
#
#                    region_name      region_geojson_name
# 0      bourgogne-franche-comté  Bourgogne-Franche-Comté
# 1      bourgogne-franche-comté  Bourgogne-Franche-Comté
# 2      bourgogne-franche-comté  Bourgogne-Franche-Comté
# 3      bourgogne-franche-comté  Bourgogne-Franche-Comté
# 4      bourgogne-franche-comté  Bourgogne-Franche-Comté
# ...                        ...                      ...
# 39140       nouvelle-calédonie       Nouvelle Calédonie
# 39141       nouvelle-calédonie       Nouvelle Calédonie
# 39142       nouvelle-calédonie       Nouvelle Calédonie
# 39143         wallis-et-futuna         Wallis-et-Futuna
# 39144         wallis-et-futuna         Wallis-et-Futuna
#
# [39145 rows x 10 columns]

# %% [markdown]
# 2/ GEOPOINTS  - Création d'une nouvelle DataFrame Concatenee pour geopoint et population

# %%
concatenated_dataframe = pd.concat([df_geopoints, df_population], axis=1) 
concatenated_dataframe.head()
# Out:
#   insee_code            city_code  Codepostaux                label  \
# 0      25620        ville du pont        25650        ville du pont
# 1      25624       villers grelot        25640       villers grelot
# 2      25615  villars les blamont        25310  villars les blamont
# 3      25619        les villedieu        25240        les villedieu
# 4      25622        villers buzon        25170        villers buzon
#
#     latitude  longitude department_name department_number  \
# 0  46.999873   6.498147           doubs                25
# 1  47.361512   6.235167           doubs                25
# 2  47.368384   6.871415           doubs                25
# 3  46.713906   6.265831           doubs                25
# 4  47.228558   5.852187           doubs                25
#
#                region_name      region_geojson_name   Code  \
# 0  bourgogne-franche-comté  Bourgogne-Franche-Comté  01001
# 1  bourgogne-franche-comté  Bourgogne-Franche-Comté  01002
# 2  bourgogne-franche-comté  Bourgogne-Franche-Comté  01004
# 3  bourgogne-franche-comté  Bourgogne-Franche-Comté  01005
# 4  bourgogne-franche-comté  Bourgogne-Franche-Comté  01006
#
#                    Libellé Population municipale 2021
# 0  L'Abergement-Clémenciat                        832
# 1    L'Abergement-de-Varey                        267
# 2        Ambérieu-en-Bugey                      14854
# 3      Ambérieux-en-Dombes                       1897
# 4                  Ambléon                        113

# %%
concatenated_dataframe['zip'] = list(zip(concatenated_dataframe['latitude'], concatenated_dataframe['longitude']))

concatenated_dataframe['zip'] 

#print(concatenated_dataframe[['latitude', 'longitude', 'zip']].head())
# Out:
# 0            (46.999873398, 6.498147193)
# 1            (47.361512085, 6.235167025)
# 2            (47.368383721, 6.871414913)
# 3             (46.713906258, 6.26583065)
# 4            (47.228558434, 5.852186748)
#                       ...
# 39140                         (nan, nan)
# 39141                         (nan, nan)
# 39142                         (nan, nan)
# 39143    (-14.270411199, -178.155263035)
# 39144    (-13.281862538, -176.161927918)
# Name: zip, Length: 39145, dtype: object

# %%
concatenated_dataframe['zip'] .isna().sum()
# Out:
# np.int64(0)

# %%
concatenated_dataframe.dropna(inplace=True)
concatenated_dataframe.tail(5)
# Out:
#       insee_code                 city_code  Codepostaux  \
# 34930      80570                   moreuil        80110
# 34931      80573    morvillers st saturnin        80290
# 34932      80587                  neslette        80140
# 34933      80595  la neuville sire bernard        80110
# 34934      80601                     nurlu        80240
#
#                           label   latitude  longitude department_name  \
# 34930                   moreuil  49.776139   2.484102           somme
# 34931    morvillers st saturnin  49.778731   1.815822           somme
# 34932                  neslette  49.927364   1.665057           somme
# 34933  la neuville sire bernard  49.743036   2.522593           somme
# 34934                     nurlu  50.004214   3.015558           somme
#
#       department_number      region_name region_geojson_name   Code  \
# 34930                80  hauts-de-france     Hauts-de-France  97613
# 34931                80  hauts-de-france     Hauts-de-France  97614
# 34932                80  hauts-de-france     Hauts-de-France  97615
# 34933                80  hauts-de-france     Hauts-de-France  97616
# 34934                80  hauts-de-france     Hauts-de-France  97617
#
#              Libellé Population municipale 2021                          zip
# 34930  M'Tsangamouji                          0  (49.776139288, 2.484101678)
# 34931       Ouangani                          0  (49.778731195, 1.815822336)
# 34932       Pamandzi                          0  (49.927364114, 1.665057388)
# 34933           Sada                          0   (49.743035523, 2.52259271)
# 34934       Tsingoni                          0  (50.004214454, 3.015558336)

# %%
concatenated_dataframe.isnull().sum()
# Out:
# insee_code                    0
# city_code                     0
# Codepostaux                   0
# label                         0
# latitude                      0
# longitude                     0
# department_name               0
# department_number             0
# region_name                   0
# region_geojson_name           0
# Code                          0
# Libellé                       0
# Population municipale 2021    0
# zip                           0
# dtype: int64

# %% [markdown]
# 3/ NEW DATAFRAME MUSEE

# %%
df_musee = pd.read_csv('./Data/musees-de-france-base-museofile.csv', sep =";")
df_musee = pd.DataFrame(df_musee)
df_musee.head(5)
# Out:
#   Identifiant                              Nom_officiel              Adresse  \
# 0       M0002                       musée de La Poterie  2 rue de Kuhlendorf
# 1       M0018                 musée des Arts Décoratifs   2 place du château
# 2       M0019                      musée des Beaux-Arts   2 place du château
# 3       M0025                        musée gallo-romain   place de la mairie
# 4       M0057  musée d'art et d'archéologie du Périgord      22 cours Tourny
#
#            Lieu Code_postal       Ville              Région Departement  \
# 0           NaN       67660  Betschdorf           Grand Est    Bas-Rhin
# 1  palais Rohan       67000  Strasbourg           Grand Est    Bas-Rhin
# 2  palais Rohan       67000  Strasbourg           Grand Est    Bas-Rhin
# 3   le Capitole       68600    Biesheim           Grand Est   Haut-Rhin
# 4         musée       24000   Périgueux  Nouvelle-Aquitaine    Dordogne
#
#                                                  URL       Telephone  ...  \
# 0  www.betschdorf.com/vie-culturelle-et-associati...  03 88 54 48 07  ...
# 1  www.musees.strasbourg.eu/musee-des-arts-decora...  03 88 52 50 08  ...
# 2      www.musees.strasbourg.eu/musee-des-beaux-arts  03 68 98 51 60  ...
# 3  www.biesheim.fr/culture-loisirs/musee-gallo-ro...  03 89 72 01 58  ...
# 4                             www.perigueux-maap.fr/  05 53 06 40 70  ...
#
#                                               Thèmes  \
# 0                        Arts décoratifs : Céramique
# 1  Arts décoratifs : Céramique, Mobilier, Horloge...
# 2                   Beaux-Arts : Peinture, Sculpture
# 3               Archéologie nationale : Gallo-romain
# 4  Antiquités étrangères : Grecques et romaines, ...
#
#                                              Artiste  \
# 0                                                NaN
# 1  Robert de Cotte, Paul et Joseph Hannong (faïen...
# 2  Giotto,  Botticelli, Raphaël, Véronèse, le Gue...
# 3                                                NaN
# 4          Oudry, Canaletto, Bouguereau, Pierre Huys
#
#                                     Personnage_phare  \
# 0                                                NaN
# 1                                    Cardinaux Rohan
# 2                                                NaN
# 3                                                NaN
# 4  Wulgrinn de Taillefer, De Mourcin, Docteur Gal...
#
#                                              Intérêt  \
# 0   Maison à pans de bois du début du XVIIIe siècle.
# 1  Palais Rohan, construit de 1739 à 1742 par Rob...
# 2  Palais Rohan, construit de 1739 à 1742 par Rob...
# 3  Bâtiment réalisé en 1991 par le cabinet Mongie...
# 4  Le bâtiment actuel a été réalisé suite à un co...
#
#                                  Protection_batiment  \
# 0                                                NaN
# 1                                                NaN
# 2  Protégé au titre des Monuments historiques : h...
# 3                                                NaN
# 4  Protégé au titre des Monuments historiques : h...
#
#                                    Protection_espace  \
# 0                                                NaN
# 1  Site patrimonial remarquable. Patrimoine mondi...
# 2  Site patrimonial remarquable. Patrimoine mondi...
# 3                                                NaN
# 4                      Site patrimonial remarquable.
#
#                              Refmer Annee_creation Date_de_mise_a_jour  \
# 0                               NaN            NaN          2023-04-12
# 1                        SPR4400040            NaN          2024-02-07
# 2             PA00085184;SPR4400040           1801          2024-02-07
# 3                               NaN            NaN          2024-02-07
# 4  PA24000099;SPR7500071;SPR7500072            NaN          2024-01-25
#
#            Coordonnees
# 0  48.900348, 7.914409
# 1  48.581229, 7.751984
# 2  48.581229, 7.751984
# 3   48.041667, 7.54802
# 4   45.186039, 0.72395
#
# [5 rows x 24 columns]

# %%
type(df_musee)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# 4/  MUSEE - add new colonne = Musée

# %%
df_musee['Musée'] = df_musee.apply(lambda _: 'Musée', axis=1)

# %%
df_musee.head(5)
# Out:
#   Identifiant                              Nom_officiel              Adresse  \
# 0       M0002                       musée de La Poterie  2 rue de Kuhlendorf
# 1       M0018                 musée des Arts Décoratifs   2 place du château
# 2       M0019                      musée des Beaux-Arts   2 place du château
# 3       M0025                        musée gallo-romain   place de la mairie
# 4       M0057  musée d'art et d'archéologie du Périgord      22 cours Tourny
#
#            Lieu Code_postal       Ville              Région Departement  \
# 0           NaN       67660  Betschdorf           Grand Est    Bas-Rhin
# 1  palais Rohan       67000  Strasbourg           Grand Est    Bas-Rhin
# 2  palais Rohan       67000  Strasbourg           Grand Est    Bas-Rhin
# 3   le Capitole       68600    Biesheim           Grand Est   Haut-Rhin
# 4         musée       24000   Périgueux  Nouvelle-Aquitaine    Dordogne
#
#                                                  URL       Telephone  ...  \
# 0  www.betschdorf.com/vie-culturelle-et-associati...  03 88 54 48 07  ...
# 1  www.musees.strasbourg.eu/musee-des-arts-decora...  03 88 52 50 08  ...
# 2      www.musees.strasbourg.eu/musee-des-beaux-arts  03 68 98 51 60  ...
# 3  www.biesheim.fr/culture-loisirs/musee-gallo-ro...  03 89 72 01 58  ...
# 4                             www.perigueux-maap.fr/  05 53 06 40 70  ...
#
#                                              Artiste  \
# 0                                                NaN
# 1  Robert de Cotte, Paul et Joseph Hannong (faïen...
# 2  Giotto,  Botticelli, Raphaël, Véronèse, le Gue...
# 3                                                NaN
# 4          Oudry, Canaletto, Bouguereau, Pierre Huys
#
#                                     Personnage_phare  \
# 0                                                NaN
# 1                                    Cardinaux Rohan
# 2                                                NaN
# 3                                                NaN
# 4  Wulgrinn de Taillefer, De Mourcin, Docteur Gal...
#
#                                              Intérêt  \
# 0   Maison à pans de bois du début du XVIIIe siècle.
# 1  Palais Rohan, construit de 1739 à 1742 par Rob...
# 2  Palais Rohan, construit de 1739 à 1742 par Rob...
# 3  Bâtiment réalisé en 1991 par le cabinet Mongie...
# 4  Le bâtiment actuel a été réalisé suite à un co...
#
#                                  Protection_batiment  \
# 0                                                NaN
# 1                                                NaN
# 2  Protégé au titre des Monuments historiques : h...
# 3                                                NaN
# 4  Protégé au titre des Monuments historiques : h...
#
#                                    Protection_espace  \
# 0                                                NaN
# 1  Site patrimonial remarquable. Patrimoine mondi...
# 2  Site patrimonial remarquable. Patrimoine mondi...
# 3                                                NaN
# 4                      Site patrimonial remarquable.
#
#                              Refmer Annee_creation Date_de_mise_a_jour  \
# 0                               NaN            NaN          2023-04-12
# 1                        SPR4400040            NaN          2024-02-07
# 2             PA00085184;SPR4400040           1801          2024-02-07
# 3                               NaN            NaN          2024-02-07
# 4  PA24000099;SPR7500071;SPR7500072            NaN          2024-01-25
#
#            Coordonnees  Musée
# 0  48.900348, 7.914409  Musée
# 1  48.581229, 7.751984  Musée
# 2  48.581229, 7.751984  Musée
# 3   48.041667, 7.54802  Musée
# 4   45.186039, 0.72395  Musée
#
# [5 rows x 25 columns]

# %% [markdown]
#     3/ MUSEE - Création Dataframe Concatenés Musée et géopoint

# %%
concat_musee_dataframe = pd.concat([df_musee, df_geopoints], axis=1) 
concat_musee_dataframe.head(5)
# Out:
#   Identifiant                              Nom_officiel              Adresse  \
# 0       M0002                       musée de La Poterie  2 rue de Kuhlendorf
# 1       M0018                 musée des Arts Décoratifs   2 place du château
# 2       M0019                      musée des Beaux-Arts   2 place du château
# 3       M0025                        musée gallo-romain   place de la mairie
# 4       M0057  musée d'art et d'archéologie du Périgord      22 cours Tourny
#
#            Lieu Code_postal       Ville              Région Departement  \
# 0           NaN       67660  Betschdorf           Grand Est    Bas-Rhin
# 1  palais Rohan       67000  Strasbourg           Grand Est    Bas-Rhin
# 2  palais Rohan       67000  Strasbourg           Grand Est    Bas-Rhin
# 3   le Capitole       68600    Biesheim           Grand Est   Haut-Rhin
# 4         musée       24000   Périgueux  Nouvelle-Aquitaine    Dordogne
#
#                                                  URL       Telephone  ...  \
# 0  www.betschdorf.com/vie-culturelle-et-associati...  03 88 54 48 07  ...
# 1  www.musees.strasbourg.eu/musee-des-arts-decora...  03 88 52 50 08  ...
# 2      www.musees.strasbourg.eu/musee-des-beaux-arts  03 68 98 51 60  ...
# 3  www.biesheim.fr/culture-loisirs/musee-gallo-ro...  03 89 72 01 58  ...
# 4                             www.perigueux-maap.fr/  05 53 06 40 70  ...
#
#   insee_code            city_code Codepostaux                label   latitude  \
# 0      25620        ville du pont       25650        ville du pont  46.999873
# 1      25624       villers grelot       25640       villers grelot  47.361512
# 2      25615  villars les blamont       25310  villars les blamont  47.368384
# 3      25619        les villedieu       25240        les villedieu  46.713906
# 4      25622        villers buzon       25170        villers buzon  47.228558
#
#   longitude department_name department_number              region_name  \
# 0  6.498147           doubs                25  bourgogne-franche-comté
# 1  6.235167           doubs                25  bourgogne-franche-comté
# 2  6.871415           doubs                25  bourgogne-franche-comté
# 3  6.265831           doubs                25  bourgogne-franche-comté
# 4  5.852187           doubs                25  bourgogne-franche-comté
#
#        region_geojson_name
# 0  Bourgogne-Franche-Comté
# 1  Bourgogne-Franche-Comté
# 2  Bourgogne-Franche-Comté
# 3  Bourgogne-Franche-Comté
# 4  Bourgogne-Franche-Comté
#
# [5 rows x 35 columns]

# %%
concat_musee_dataframe = pd.concat([df_musee, df_geopoints], axis=1) 
concat_musee_dataframe.head()
# Out:
#   Identifiant                              Nom_officiel              Adresse  \
# 0       M0002                       musée de La Poterie  2 rue de Kuhlendorf
# 1       M0018                 musée des Arts Décoratifs   2 place du château
# 2       M0019                      musée des Beaux-Arts   2 place du château
# 3       M0025                        musée gallo-romain   place de la mairie
# 4       M0057  musée d'art et d'archéologie du Périgord      22 cours Tourny
#
#            Lieu Code_postal       Ville              Région Departement  \
# 0           NaN       67660  Betschdorf           Grand Est    Bas-Rhin
# 1  palais Rohan       67000  Strasbourg           Grand Est    Bas-Rhin
# 2  palais Rohan       67000  Strasbourg           Grand Est    Bas-Rhin
# 3   le Capitole       68600    Biesheim           Grand Est   Haut-Rhin
# 4         musée       24000   Périgueux  Nouvelle-Aquitaine    Dordogne
#
#                                                  URL       Telephone  ...  \
# 0  www.betschdorf.com/vie-culturelle-et-associati...  03 88 54 48 07  ...
# 1  www.musees.strasbourg.eu/musee-des-arts-decora...  03 88 52 50 08  ...
# 2      www.musees.strasbourg.eu/musee-des-beaux-arts  03 68 98 51 60  ...
# 3  www.biesheim.fr/culture-loisirs/musee-gallo-ro...  03 89 72 01 58  ...
# 4                             www.perigueux-maap.fr/  05 53 06 40 70  ...
#
#   insee_code            city_code Codepostaux                label   latitude  \
# 0      25620        ville du pont       25650        ville du pont  46.999873
# 1      25624       villers grelot       25640       villers grelot  47.361512
# 2      25615  villars les blamont       25310  villars les blamont  47.368384
# 3      25619        les villedieu       25240        les villedieu  46.713906
# 4      25622        villers buzon       25170        villers buzon  47.228558
#
#   longitude department_name department_number              region_name  \
# 0  6.498147           doubs                25  bourgogne-franche-comté
# 1  6.235167           doubs                25  bourgogne-franche-comté
# 2  6.871415           doubs                25  bourgogne-franche-comté
# 3  6.265831           doubs                25  bourgogne-franche-comté
# 4  5.852187           doubs                25  bourgogne-franche-comté
#
#        region_geojson_name
# 0  Bourgogne-Franche-Comté
# 1  Bourgogne-Franche-Comté
# 2  Bourgogne-Franche-Comté
# 3  Bourgogne-Franche-Comté
# 4  Bourgogne-Franche-Comté
#
# [5 rows x 35 columns]

# %%
concat_musee_dataframe = concat_musee_dataframe.drop(['region_geojson_name', 'department_number', 'insee_code', 'Coordonnees'], axis=1)

# %%
concat_musee_dataframe.head(5)
# Out:
#   Identifiant                              Nom_officiel              Adresse  \
# 0       M0002                       musée de La Poterie  2 rue de Kuhlendorf
# 1       M0018                 musée des Arts Décoratifs   2 place du château
# 2       M0019                      musée des Beaux-Arts   2 place du château
# 3       M0025                        musée gallo-romain   place de la mairie
# 4       M0057  musée d'art et d'archéologie du Périgord      22 cours Tourny
#
#            Lieu Code_postal       Ville              Région Departement  \
# 0           NaN       67660  Betschdorf           Grand Est    Bas-Rhin
# 1  palais Rohan       67000  Strasbourg           Grand Est    Bas-Rhin
# 2  palais Rohan       67000  Strasbourg           Grand Est    Bas-Rhin
# 3   le Capitole       68600    Biesheim           Grand Est   Haut-Rhin
# 4         musée       24000   Périgueux  Nouvelle-Aquitaine    Dordogne
#
#                                                  URL       Telephone  ...  \
# 0  www.betschdorf.com/vie-culturelle-et-associati...  03 88 54 48 07  ...
# 1  www.musees.strasbourg.eu/musee-des-arts-decora...  03 88 52 50 08  ...
# 2      www.musees.strasbourg.eu/musee-des-beaux-arts  03 68 98 51 60  ...
# 3  www.biesheim.fr/culture-loisirs/musee-gallo-ro...  03 89 72 01 58  ...
# 4                             www.perigueux-maap.fr/  05 53 06 40 70  ...
#
#   Annee_creation Date_de_mise_a_jour  Musée            city_code Codepostaux  \
# 0            NaN          2023-04-12  Musée        ville du pont       25650
# 1            NaN          2024-02-07  Musée       villers grelot       25640
# 2           1801          2024-02-07  Musée  villars les blamont       25310
# 3            NaN          2024-02-07  Musée        les villedieu       25240
# 4            NaN          2024-01-25  Musée        villers buzon       25170
#
#                  label   latitude longitude department_name  \
# 0        ville du pont  46.999873  6.498147           doubs
# 1       villers grelot  47.361512  6.235167           doubs
# 2  villars les blamont  47.368384  6.871415           doubs
# 3        les villedieu  46.713906  6.265831           doubs
# 4        villers buzon  47.228558  5.852187           doubs
#
#                region_name
# 0  bourgogne-franche-comté
# 1  bourgogne-franche-comté
# 2  bourgogne-franche-comté
# 3  bourgogne-franche-comté
# 4  bourgogne-franche-comté
#
# [5 rows x 31 columns]

# %%
4/ MUSEE - drop NAN for dataframe concatenee musee et geopoint

# %%
concat_musee_dataframe.isna().sum()
# Out:
# Identifiant            37919
# Nom_officiel           37919
# Adresse                37948
# Lieu                   38663
# Code_postal            37919
# Ville                  37919
# Région                 37919
# Departement            37919
# URL                    38005
# Telephone              37945
# Categorie              38815
# Domaine_thematique     37964
# Histoire               37974
# Atout                  37984
# Thèmes                 38065
# Artiste                38639
# Personnage_phare       38615
# Intérêt                38194
# Protection_batiment    38651
# Protection_espace      38366
# Refmer                 38365
# Annee_creation         38996
# Date_de_mise_a_jour    37919
# Musée                  37919
# city_code                  0
# Codepostaux                0
# label                      0
# latitude                 211
# longitude                211
# department_name            0
# region_name                0
# dtype: int64

# %% [markdown]
# 4/ MUSEE  - drop NAN

# %%
concat_musee_dataframe.dropna()
# Out:
#     Identifiant                              Nom_officiel  \
# 24        M0133                 musée du Vin de Bourgogne
# 38        M0191                              musée Zervos
# 275       M0150  musée d'Art et d'Histoire Romain Rolland
# 907       M0878                      musée des beaux-arts
#
#                        Adresse  \
# 24   rue d'Enfer - rue Paradis
# 38           rue Saint-Étienne
# 275    avenue de la République
# 907      3 avenue de la Madone
#
#                                                   Lieu Code_postal    Ville  \
# 24                                      hôtel des ducs       21200   Beaune
# 38                               Maison Romain-Rolland       89450  Vézelay
# 275  hôtel de Bellegarde maison natale de Romain Ro...       58500  Clamecy
# 907                                 palais de Carnolès       06500   Menton
#
#                          Région      Departement  \
# 24      Bourgogne-Franche-Comté        Côte-d'Or
# 38      Bourgogne-Franche-Comté            Yonne
# 275     Bourgogne-Franche-Comté           Nièvre
# 907  Provence-Alpes-Côte d'Azur  Alpes-Maritimes
#
#                                                    URL       Telephone  ...  \
# 24                  www.beaune.fr/spip.php?rubrique171  03 80 22 08 19  ...
# 38   www.yonne.fr/Culture-et-Vie-Locale/Sites-et-mo...  03 86 32 39 26  ...
# 275  www.clamecy.fr/index.php/Mus%C3%A9e-d-Art-et-d...  03 86 27 17 99  ...
# 907  www.menton.fr/Musee-des-Beaux-Arts-Palais-de-C...  04 89 81 52 92  ...
#
#     Annee_creation Date_de_mise_a_jour  Musée             city_code  \
# 24            1946          2024-02-07  Musée         ciry salsogne
# 38            2006          2024-01-25  Musée          osly courtil
# 275           1876          2024-02-07  Musée        poids de fiole
# 907           1977          2024-02-02  Musée  verrey sous salmaise
#
#     Codepostaux                 label   latitude longitude department_name  \
# 24         2220         ciry salsogne  49.367262  3.467612           aisne
# 38         2290          osly courtil  49.399370  3.237910           aisne
# 275       39570        poids de fiole  46.594689  5.622458            jura
# 907       21690  verrey sous salmaise  47.438445  4.674579       côte-d'or
#
#                  region_name
# 24           hauts-de-france
# 38           hauts-de-france
# 275  bourgogne-franche-comté
# 907  bourgogne-franche-comté
#
# [4 rows x 31 columns]

# %%
print(type(concat_musee_dataframe))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#concat_musee_dataframe.fillna(0).astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 concat_musee_dataframe.fillna(0).astype(int)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/internals/blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/dtypes/astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/dtypes/astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: 'M0002'

# %% [markdown]
# 4/ MUSEE - change word musee for Musee

# %%
word = 'musee' 

for i, word in enumerate(concat_musee_dataframe['Nom_officiel']):

    if isinstance(word, str) and word[0].islower():
  
        formatted_word = word[0].upper() + word[1:].lower()

        concat_musee_dataframe = concat_musee_dataframe.at[i, 'Nom_officiel'] = formatted_word
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 9
#       5 if isinstance(word, str) and word[0].islower():
#       7     formatted_word = word[0].upper() + word[1:].lower()
# ----> 9     concat_musee_dataframe = concat_musee_dataframe.at[i, 'Nom_officiel'] = formatted_word
#
# AttributeError: 'str' object has no attribute 'at'

# %%
concat_musee_dataframe['Nom_officiel'] = concat_musee_dataframe['Nom_officiel'].apply(lambda word: word[0].upper() + word[1:].lower() if isinstance(word, str) and word[0].islower() else word)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 concat_musee_dataframe['Nom_officiel'] = concat_musee_dataframe['Nom_officiel'].apply(lambda word: word[0].upper() + word[1:].lower() if isinstance(word, str) and word[0].islower() else word)
#
# TypeError: string indices must be integers

# %%
concat_musee_dataframe['Nom_officiel'].dtype()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 concat_musee_dataframe['Nom_officiel'].dtype()
#
# TypeError: string indices must be integers

# %%
concat_musee_dataframe['Nom_officiel'].head(5)

# %%
concat_musee_dataframe.columns

# %%
concat_musee_dataframe(['Identifiant', 'Nom_officiel', 'Adresse', 'Lieu', 'Code_postal',
       'Ville', 'Région', 'Departement', 'URL', 'Telephone', 'Categorie',
       'Domaine_thematique', 'Histoire', 'Atout', 'Thèmes', 'Artiste',
       'Personnage_phare', 'Intérêt', 'Protection_batiment',
       'Protection_espace', 'Refmer', 'Annee_creation', 'Date_de_mise_a_jour',
       'Musée', 'city_code', 'Codepostaux', 'label', 'latitude', 'longitude',
       'department_name', 'region_name'], axis=1, inplace=True)

# %%
concat_musee_dataframe = concat_musee_dataframe(['Identifiant', 'Nom_officiel', 'Adresse', 'Lieu', 'Code_postal', 
    'Ville', 'Région', 'Departement', 'URL', 'Telephone', 'Categorie', 
    'Domaine_thematique', 'Histoire', 'Atout', 'Thèmes', 'Artiste', 
    'Personnage_phare', 'Intérêt', 'Protection_batiment', 'Protection_espace', 
    'Refmer', 'Annee_creation', 'Date_de_mise_a_jour', 'Musée', 'city_code', 
    'Codepostaux', 'label', 'latitude', 'longitude', 'department_name', 
    'region_name'], axis=1, inplace=True)

# %% [markdown]
# 5/ NEW ARCHITECTURE DATAFRAME

# %%
df_site_architecture = pd.read_csv('./Data/liste-des-edifices-labellises-architecture-contemporaine-remarquable-acr.csv', sep =";")

# %%
df_site_architecture .head(5)
# Out:
#   Reference_de_la_notice Ancienne_reference_de_la_notice_RENV  \
# 0             ACR0000015                                  NaN
# 1             ACR0000016                                  NaN
# 2             ACR0000032                           EA74141229
# 3             ACR0000042                                  NaN
# 4             ACR0000028                                  NaN
#
#                                    Cadre_de_l_etude                Région  \
# 0  Labellisé Architecture contemporaine remarquable  Auvergne-Rhône-Alpes
# 1  Labellisé Architecture contemporaine remarquable  Auvergne-Rhône-Alpes
# 2  Labellisé Architecture contemporaine remarquable  Auvergne-Rhône-Alpes
# 3  Labellisé Architecture contemporaine remarquable  Auvergne-Rhône-Alpes
# 4  Labellisé Architecture contemporaine remarquable  Auvergne-Rhône-Alpes
#
#    Numero_departement                    Commune Ancien_nom_commune  INSEE  \
# 0                26.0  Donzère;La Garde-Adhémart                NaN  26116
# 1                26.0   Chapelle-en-Vercors (La)                NaN  26074
# 2                74.0                     Annecy                NaN  74010
# 3                74.0                     Cluses                NaN  74081
# 4                26.0                    Valence                NaN  26362
#
#          Lieudit                                 Adresse_normalisee  ...  \
# 0            NaN  Route départementale 358 ; Pierrelatte (route de)  ...
# 1  Les Aubaneaux                                                NaN  ...
# 2            NaN  Lycée (boulevard du) 3 bis, 5, 7 ; Francs-Tire...  ...
# 3            NaN                              Sardagne (avenue de )  ...
# 4            NaN                           Victor Hugo (avenue) 378  ...
#
#   Partie_d_elevation_exterieure Materiaux_de_la_couverture Typologie_de_plan  \
# 0                           NaN                        NaN               NaN
# 1                           NaN                        NaN               NaN
# 2                           NaN                        NaN               NaN
# 3                           NaN                        NaN               NaN
# 4                           NaN                        NaN               NaN
#
#   Technique_du_decor_porte_de_l_edifice Indexation_iconographique_normalisee  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
#
#   Description_de_l_elevation_interieure Emplacement_forme_structure_escalier  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
#
#   etat_de_conservation                           Description_de_l_edifice  \
# 0                  NaN  Pont d'une seule voie constitué par deux tabli...
# 1                  NaN  La ferme des Aubaneaux a été reconstruite en a...
# 2                  NaN  Il s’agit d’un ensemble de 3 immeubles formant...
# 3                  NaN                                                NaN
# 4                  NaN  Le bâtiment principal de la station service, c...
#
#     Commune_forme_editoriale
# 0  Donzère;La Garde-Adhémart
# 1     La Chapelle-en-Vercors
# 2                     Annecy
# 3                     Cluses
# 4                    Valence
#
# [5 rows x 44 columns]

# %% [markdown]
# 5/ ARCHITECTURE - Add new column Site Architectural

# %%
df_site_architecture['Site architectural'] = df_site_architecture.apply(lambda _: 'Site architectural', axis=1)

# %%
df_site_architecture['Titre_courant'].head(30)
# Out:
# 0                  pont à hauban dit pont Albert-Caquot
# 1                              ferme dite Les Aubaneaux
# 2     ensemble de trois immeubles, dit Résidence La ...
# 3                                   cité de La Sardagne
# 4                         station-service Relais du Sud
# 5                          Église Saint-Joseph-des-Fins
# 6     immeubles de la zone d'urbanisation prioritair...
# 7     gare inférieure du téléphérique des Grandes-Pl...
# 8                   "maison dite ""Maison à Pélo Ben"""
# 9                  Bâtiment thermal Jules-Louis Chardon
# 10                        Église dite centre œcuménique
# 11    "zone d'aménagement concerté dite "logements d...
# 12                                         bibliothèque
# 13            École nationale supérieure d'architecture
# 14                               barrage dit Le Chambon
# 15           foyer de travailleurs dit foyer Clairvivre
# 16                               Cité H.L.M. Beaulieu I
# 17              immeuble de bureaux de la Société ALGOE
# 18       immeuble de bureaux de la société Total France
# 19                                     cité Les Etoiles
# 20        Cité HBM dite Cité Perrache, actuellement HLM
# 21                                    immeuble Curtelin
# 22    couvent, aujourd'hui groupe scolaire, dit exte...
# 23                        immeuble, dit Palais de Flore
# 24    Eglise de l’Immaculé-Conception dite aussi Not...
# 25    Cité, dite les Gratte-ciel (théâtre national p...
# 26               immeubles de la Résidence La Péralière
# 27                            Chapelle de la Giraudière
# 28                               maison dite Le Méruzin
# 29    institut de recherche dit Centre de l'Institut...
# Name: Titre_courant, dtype: object

# %%
print(df_site_architecture.columns)

# %%
df_site_architecture = df_site_architecture.drop(['Reference_de_la_notice', 'Ancienne_reference_de_la_notice_RENV',
       'Cadre_de_l_etude', 'Ancien_nom_commune', 
       'Adresse_forme_editoriale', 'References_cadastrales','Vocable___pour_les_edifices_cultuels',
       'Dénominations', 'Destination_actuelle_de_l_edifice','Date_de_Label', 'Precisions_sur_l_interet',
       'Statut_juridique_du_proprietaire',
       'Etablissement_affectataire_de_l_edifice',
       'Auteur_de_la_photographie_autp', 
       'Materiaux_du_gros_oeuvre', 'Type_de_couverture',
       'Partie_d_elevation_exterieure', 'Materiaux_de_la_couverture',
       'Typologie_de_plan', 'Technique_du_decor_porte_de_l_edifice',
       'Indexation_iconographique_normalisee',
       'Description_de_l_elevation_interieure',
       'Emplacement_forme_structure_escalier', 'etat_de_conservation',
       'Commune_forme_editoriale', 'Elements_remarquables_dans_l_edifice', 
       'Lieudit', 'Siecle_de_la_campagne_principale_de_construction', 'Siecle_de_campagne_secondaire_de_construction', 'Datation_de_l_edifice',  'Liens_externes', 'Acces_memoire_WEB', 'Observations'], axis=1)

# %%
df_site_architecture
# Out:
#                     Région  Numero_departement                    Commune  \
# 0     Auvergne-Rhône-Alpes                26.0  Donzère;La Garde-Adhémart
# 1     Auvergne-Rhône-Alpes                26.0   Chapelle-en-Vercors (La)
# 2     Auvergne-Rhône-Alpes                74.0                     Annecy
# 3     Auvergne-Rhône-Alpes                74.0                     Cluses
# 4     Auvergne-Rhône-Alpes                26.0                    Valence
# ...                    ...                 ...                        ...
# 1771       Hauts-de-France                62.0                     Divion
# 1772       Hauts-de-France                80.0                  Abbeville
# 1773             Grand Est                57.0                       Metz
# 1774             Grand Est                57.0                 Thionville
# 1775              Bretagne                22.0               Saint-Brieuc
#
#       INSEE                                 Adresse_normalisee  \
# 0     26116  Route départementale 358 ; Pierrelatte (route de)
# 1     26074                                                NaN
# 2     74010  Lycée (boulevard du) 3 bis, 5, 7 ; Francs-Tire...
# 3     74081                              Sardagne (avenue de )
# 4     26362                           Victor Hugo (avenue) 378
# ...     ...                                                ...
# 1771  62270                                      Pasteur (rue)
# 1772  80001                                Max-Lejeune (place)
# 1773  57042                                     Ney (avenue) 3
# 1774  57672                      Robert Schumann (boulevard) 2
# 1775  22278                       Combat des Trente (rue du) 8
#
#                               Coordonnees  \
# 0                       44.44424, 4.71027
# 1                      44.974803, 5.40436
# 2     45.9058277995876, 6.124396526131411
# 3                                     NaN
# 4                     44.913098, 4.884487
# ...                                   ...
# 1771                                  NaN
# 1772                                  NaN
# 1773                                  NaN
# 1774                                  NaN
# 1775                                  NaN
#
#                                           Titre_courant    Département  \
# 0                  pont à hauban dit pont Albert-Caquot          Drôme
# 1                              ferme dite Les Aubaneaux          Drôme
# 2     ensemble de trois immeubles, dit Résidence La ...   Haute-Savoie
# 3                                   cité de La Sardagne   Haute-Savoie
# 4                         station-service Relais du Sud          Drôme
# ...                                                 ...            ...
# 1771                                  Piscine Tournesol  Pas-de-Calais
# 1772                         hôtel de ville et sa place          Somme
# 1773                            Arsenal : Cite musicale        Moselle
# 1774                  Immeuble de logements L'européen        Moselle
# 1775                             ancien cinéma Le Royal  Côtes-d'Armor
#
#                                  Description_historique  \
# 0     Le pont a été construit par Albert Caquot sur ...
# 1     Suite aux bombardements, pillage et incendie d...
# 2     Ensemble de trois immeubles de logements dits ...
# 3                                                   NaN
# 4     La station service « le Relais du Sud » a été ...
# ...                                                 ...
# 1771                                                NaN
# 1772                                                NaN
# 1773  "Livré en 1989, l’Arsenal – Cité musicale de M...
# 1774  Né à Rome en 1924, Lanfranco Virgili cumule se...
# 1775  "L'inscription dans le plan de la ville des pr...
#
#                                     Auteur_de_l_edifice  \
# 0                            Caquot Albert (architecte)
# 1     Descottes-Genon Marcel (architecte);Sabatou Je...
# 2     Cottard Robert (architecte);Charlier Robert (m...
# 3     Novarina Maurice (architecte);Plottier Richard...
# 4                                           Garin Henri
# ...                                                 ...
# 1771  Schoeller Bernard (architecte);Constantinidis ...
# 1772  Gréber Jacques (architecte);Gréber Pierre (arc...
# 1773  Bofill Ricardo (architecte mandataire);Longo A...
# 1774          Virgili Lanfranco (architecte mandataire)
# 1775  Fauny Jean (architecte);Hédou de la Héraudière...
#
#                                Description_de_l_edifice  Site architectural
# 0     Pont d'une seule voie constitué par deux tabli...  Site architectural
# 1     La ferme des Aubaneaux a été reconstruite en a...  Site architectural
# 2     Il s’agit d’un ensemble de 3 immeubles formant...  Site architectural
# 3                                                   NaN  Site architectural
# 4     Le bâtiment principal de la station service, c...  Site architectural
# ...                                                 ...                 ...
# 1771                                                NaN  Site architectural
# 1772                                                NaN  Site architectural
# 1773  L’Arsenal – Cité musicale est situé à la limit...  Site architectural
# 1774  La commande du bâtiment L’Européen a été passé...  Site architectural
# 1775  "Construction, décors et matériaux Structurell...  Site architectural
#
# [1776 rows x 12 columns]

# %%
df_site_architecture

# %% [markdown]
# 5/ ARCHITECTURE - Split Coordonées for Architecture

# %%
df_site_architecture['Coordonnees'] = df_site_architecture['Coordonnees'].fillna('')

# %%
df_site_architecture

# %%
df_site_architecture[['latitude', 'longitude']] = df_site_architecture['Coordonnees'].str.split(', ', expand=True)
df_site_architecture
# Out:
#                     Région  Numero_departement                    Commune  \
# 0     Auvergne-Rhône-Alpes                26.0  Donzère;La Garde-Adhémart
# 1     Auvergne-Rhône-Alpes                26.0   Chapelle-en-Vercors (La)
# 2     Auvergne-Rhône-Alpes                74.0                     Annecy
# 3     Auvergne-Rhône-Alpes                74.0                     Cluses
# 4     Auvergne-Rhône-Alpes                26.0                    Valence
# ...                    ...                 ...                        ...
# 1771       Hauts-de-France                62.0                     Divion
# 1772       Hauts-de-France                80.0                  Abbeville
# 1773             Grand Est                57.0                       Metz
# 1774             Grand Est                57.0                 Thionville
# 1775              Bretagne                22.0               Saint-Brieuc
#
#       INSEE                                 Adresse_normalisee  \
# 0     26116  Route départementale 358 ; Pierrelatte (route de)
# 1     26074                                                NaN
# 2     74010  Lycée (boulevard du) 3 bis, 5, 7 ; Francs-Tire...
# 3     74081                              Sardagne (avenue de )
# 4     26362                           Victor Hugo (avenue) 378
# ...     ...                                                ...
# 1771  62270                                      Pasteur (rue)
# 1772  80001                                Max-Lejeune (place)
# 1773  57042                                     Ney (avenue) 3
# 1774  57672                      Robert Schumann (boulevard) 2
# 1775  22278                       Combat des Trente (rue du) 8
#
#                               Coordonnees  \
# 0                       44.44424, 4.71027
# 1                      44.974803, 5.40436
# 2     45.9058277995876, 6.124396526131411
# 3                                     NaN
# 4                     44.913098, 4.884487
# ...                                   ...
# 1771                                  NaN
# 1772                                  NaN
# 1773                                  NaN
# 1774                                  NaN
# 1775                                  NaN
#
#                                           Titre_courant    Département  \
# 0                  pont à hauban dit pont Albert-Caquot          Drôme
# 1                              ferme dite Les Aubaneaux          Drôme
# 2     ensemble de trois immeubles, dit Résidence La ...   Haute-Savoie
# 3                                   cité de La Sardagne   Haute-Savoie
# 4                         station-service Relais du Sud          Drôme
# ...                                                 ...            ...
# 1771                                  Piscine Tournesol  Pas-de-Calais
# 1772                         hôtel de ville et sa place          Somme
# 1773                            Arsenal : Cite musicale        Moselle
# 1774                  Immeuble de logements L'européen        Moselle
# 1775                             ancien cinéma Le Royal  Côtes-d'Armor
#
#                                  Description_historique  \
# 0     Le pont a été construit par Albert Caquot sur ...
# 1     Suite aux bombardements, pillage et incendie d...
# 2     Ensemble de trois immeubles de logements dits ...
# 3                                                   NaN
# 4     La station service « le Relais du Sud » a été ...
# ...                                                 ...
# 1771                                                NaN
# 1772                                                NaN
# 1773  "Livré en 1989, l’Arsenal – Cité musicale de M...
# 1774  Né à Rome en 1924, Lanfranco Virgili cumule se...
# 1775  "L'inscription dans le plan de la ville des pr...
#
#                                     Auteur_de_l_edifice  \
# 0                            Caquot Albert (architecte)
# 1     Descottes-Genon Marcel (architecte);Sabatou Je...
# 2     Cottard Robert (architecte);Charlier Robert (m...
# 3     Novarina Maurice (architecte);Plottier Richard...
# 4                                           Garin Henri
# ...                                                 ...
# 1771  Schoeller Bernard (architecte);Constantinidis ...
# 1772  Gréber Jacques (architecte);Gréber Pierre (arc...
# 1773  Bofill Ricardo (architecte mandataire);Longo A...
# 1774          Virgili Lanfranco (architecte mandataire)
# 1775  Fauny Jean (architecte);Hédou de la Héraudière...
#
#                                Description_de_l_edifice  Site architectural  \
# 0     Pont d'une seule voie constitué par deux tabli...  Site architectural
# 1     La ferme des Aubaneaux a été reconstruite en a...  Site architectural
# 2     Il s’agit d’un ensemble de 3 immeubles formant...  Site architectural
# 3                                                   NaN  Site architectural
# 4     Le bâtiment principal de la station service, c...  Site architectural
# ...                                                 ...                 ...
# 1771                                                NaN  Site architectural
# 1772                                                NaN  Site architectural
# 1773  L’Arsenal – Cité musicale est situé à la limit...  Site architectural
# 1774  La commande du bâtiment L’Européen a été passé...  Site architectural
# 1775  "Construction, décors et matériaux Structurell...  Site architectural
#
#               latitude          longitude
# 0             44.44424            4.71027
# 1            44.974803            5.40436
# 2     45.9058277995876  6.124396526131411
# 3                  NaN                NaN
# 4            44.913098           4.884487
# ...                ...                ...
# 1771               NaN                NaN
# 1772               NaN                NaN
# 1773               NaN                NaN
# 1774               NaN                NaN
# 1775               NaN                NaN
#
# [1776 rows x 14 columns]

# %%
df_site_architecture.to_csv('architecture.csv', index=False)
